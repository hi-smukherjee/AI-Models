# %% [markdown]
# <a href="https://colab.research.google.com/github/hi-smukherjee/AI-Models/blob/main/BuildingsDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import necessary libraries
import glob
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image

from tensorflow.python.keras import Model
from tensorflow.python.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, Concatenate, Dropout
